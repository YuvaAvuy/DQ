# %% [markdown]
# <a href="https://colab.research.google.com/github/YuvaAvuy/DQ/blob/main/DV_assignments.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.sankey import Sankey

# Load the dataset from the CSV file
df = pd.read_csv('Ecommerce.csv')

# Aggregate data to count clicks and purchases for each product and category
product_click_counts = df[df['action'] == 'click']['product_name'].value_counts()
product_purchase_counts = df[df['action'] == 'purchase']['product_name'].value_counts()


# Create bar charts for products
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
product_click_counts.plot(kind='bar', title='Product Click Counts')
plt.subplot(1, 2, 2)
product_purchase_counts.plot(kind='bar', title='Product Purchase Counts')

# Task 2: Analyze User Click Patterns
# Create pie charts for categories
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
product_click_counts.plot(kind='pie', autopct='%1.1f%%', title='Product Click Counts')
plt.subplot(1, 2, 2)
product_purchase_counts.plot(kind='pie', autopct='%1.1f%%', title='Product Purchase Counts')


# Create Sankey diagram
fig, ax = plt.subplots()
sankey = Sankey(ax=ax, unit=None)
sankey.add(flows=[1, 1, -1, -1], labels=['Click', 'Purchase', 'Click', 'Purchase'], orientations=[0, 1, -1, 1], rotation=45)
diagrams = sankey.finish()

# Display the visualizations
plt.tight_layout()
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-7e109747f3fc> in <cell line: 15>()
#      13 # Define the statistics
#      14 statistics = ['Points', 'Assists', 'Rebounds']
# ---> 15 data = player_data[statistics].values[5]
#      16
#      17 # Create a radar-like chart
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3811             if is_iterator(key):
#    3812                 key = list(key)
# -> 3813             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3814
#    3815         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    6068             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    6069
# -> 6070         self._raise_if_missing(keyarr, indexer, axis_name)
#    6071
#    6072         keyarr = self.take(indexer)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in _raise_if_missing(self, key, indexer, axis_name)
#    6128                 if use_interval_msg:
#    6129                     key = list(key)
# -> 6130                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6131
#    6132             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#
# KeyError: "None of [Index(['Points', 'Assists', 'Rebounds'], dtype='object')] are in the [columns]"

# %%
import pandas as pd
import plotly.express as px

# Load the dataset
df = pd.read_csv('Studentdata.csv')

# Create a box plot
fig = px.box(df, x='Grade', y='Test_Score', title='Box Plot of Test Scores by Grade')
fig.show()
# Create a scatter plot
# Create a scatter plot with names as labels
fig = px.scatter(df, x='Attendance', y='Test_Score', color='Grade',
                 text='Name',  # Add 'Name' as labels
                 title='Scatter Plot of Test Scores vs. Attendance with Student Names',
                 labels={'Attendance': 'Attendance (%)', 'Test_Score': 'Test Score'})
fig.update_traces(textposition='top center')  # Adjust the label position
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="0995d7c3-4be4-4b9d-b179-4a18fc1c0e9c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0995d7c3-4be4-4b9d-b179-4a18fc1c0e9c")) {                    Plotly.newPlot(                        "0995d7c3-4be4-4b9d-b179-4a18fc1c0e9c",                        [{"alignmentgroup":"True","hovertemplate":"Grade=%{x}\u003cbr\u003eTest_Score=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x":["D","B","C","A","F","B","C","A","D","A"],"x0":" ","xaxis":"x","y":[85,88,72,94,60,86,78,92,70,89],"y0":" ","yaxis":"y","type":"box"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidt ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="b5c814b8-3ce8-410b-b855-c459d6b039d6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b5c814b8-3ce8-410b-b855-c459d6b039d6")) {                    Plotly.newPlot(                        "b5c814b8-3ce8-410b-b855-c459d6b039d6",                        [{"hovertemplate":"Grade=D\u003cbr\u003eAttendance (%)=%{x}\u003cbr\u003eTest Score=%{y}\u003cbr\u003eName=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"D","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers+text","name":"D","orientation":"v","showlegend":true,"text":["John","William"],"x":[90,80],"xaxis":"x","y":[85,70],"yaxis":"y","type":"scatter","textposition":"top center"},{"hovertemplate":"Grade=B\u003cbr\u003eAttendance (%)=%{x}\u003cbr\u003eTest Score=%{y}\u003cbr\u003eName=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"B","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers+text","name":"B","orientation":"v","showlegend":true,"text":["Sarah","Laura"],"x":[95,92],"xaxis":"x","y":[88,86],"yaxis":"y","type":"scatter","textposition":"top center"},{"hovertemplate":"Grade=C\u003cbr\u003eAttendance (%)=%{x}\u003cbr\u003eTest Score=%{y}\u003cbr\u003eName=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"C","marker":{"color":"#00cc96","symbol":"circle"},"mode":"markers+text","name":"C","orientation":"v","showlegend":true,"text":["Michael","David"],"x":[85,88],"xaxis":"x","y":[72,78],"yaxis":"y","type":"scatter","textposition":"top center"},{"hovertemplate":"Grade=A\u003cbr\u003eAttendance (%)=%{x}\u003cbr\u003eTest Score=%{y}\u003cbr\u003eName=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"A","marker":{"color":"#ab63fa","symbol":"circle"},"mode":"markers+text","name":"A","orientation":"v","showlegend":true,"text":["Emily","Olivia","Emma"],"x":[100,99,97],"xaxis":"x","y":[94,92,89],"yaxis":"y","type":"scatter","textposition":"top center"},{"hovertemplate":"Grade=F\u003cbr\u003eAttendance (%)=%{x}\u003cbr\u003eTest Score=%{y}\u003cbr\u003eName=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"F","marker":{"color":"#FFA15A","symbol":"circle"},"mode":"markers+text","name":"F","orientation":"v","showlegend":true,"text":["James"],"x":[70],"xaxis":"x","y":[60],"yaxis":"y","type":"scatter","textposition":"top center"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0 ...
